# %%
# imports and options
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(r"G:\Shared drives\sq1 - marketing\seo\Competitor Analysis\Backlinks\CAAQuebecBLs 2023 Q1\CAAQuebecBLs.csv")

# assign new dataframes
product = df.loc[df['Type'] == 'Product']
campaign = df.loc[df['Type'] == 'Campaign']
tool = df.loc[df['Type'] == 'Tool']
partnership = df.loc[df['Type'] == 'Partnership']
blog = df.loc[df['Type'] == 'Blog']

# %%
# opportunities in tools

blog.iloc[0:10]
# Out:
#                                                                                                                                                                                                       URL  \
# 6                                                                 https://www.caaquebec.com/en/on-the-road/advice/tips-and-tricks/tip-and-trick/show/sujet/windshield-wipers-everything-you-need-to-know/
# 10                                                                                            https://www.caaquebec.com/fr/sur-la-route/interets-publics/dossier-essence/composantes-du-prix-de-lessence/
# 13                                                                        https://www.caaquebec.com/en/on-the-road/advice/tips-and-tricks/tip-and-trick/show/sujet/driving-an-electric-vehicle-in-winter/
# ...
