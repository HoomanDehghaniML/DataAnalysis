# %%
### Safe to rerun ###

import config
import gspread
import json
import openai
import os

import numpy as np
import pandas as pd

# Authorize gspread
gc, authorized_user = gspread.oauth_from_dict(config.gspread_secret_key_personal, config.gspread_auth_key_personal)

# Read Input from directory

directory = r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Output\Current"

## List all CSV files in the directory

urls = [os.path.join(directory, filename) for filename in os.listdir(directory) if filename.endswith('.xlsx')]

if len(urls) > 1:
    df = pd.concat([pd.read_excel(url) for url in urls], ignore_index=True)

else: 
    df = pd.read_excel(urls[0])

# Create a variable for the title of the project
for filename in os.listdir(directory):
    if filename.endswith('.xlsx'):
        # Capture the cryptic name
        artifact_name = filename
        
        # Extract the essence
        title = artifact_name.split('.')[0]

# Load records.json into a python dictionary titled records
with open(r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Records.json", "r") as records_json:
    records = json.load(records_json)

# Check if an entry in records exists with title
if title not in records:
    records[title] = {
        'New': 'True',
        'Last': ''
    }

records
# Out:
# {'fthb': {'New': 'False',
#   'Last': 'https://www.wkbw.com/financial-fitness/eager-buyers-are-skipping-home-inspections-is-it-too-risky'},
#  'wfh': {'New': 'False',
#   'Last': 'https://www.ipma.world/how-to-work-remotely/'}}

# %%
### Safe to rerun ###
# Clean up the data #

# Make df json compliant
df = df.applymap(str)
df.replace("nan", "", inplace=True)
df = df.applymap(str.strip)

# Remove rows where email is empty
Recipient_null = df.loc[:, 'Recipient'] == ""
df = df.loc[~Recipient_null]

# Reset index
df = df.reset_index(drop=True)

# %%
### Safe to rerun ###
# Prepare the batch #

# TODO: drop Anchor, DR
df = df.drop(columns=['Anchor', 'Domain rating'])

# Create the dic variable
dic = records.get(title)

# if dataframe is new, batch = df.loc[0:30,:]
if dic.get("New") == "True":
    batch = df.loc[0:30,:]

# if dataframe is old, batch = the next 30 after "Last"
if dic.get("New") == "False":

    # Get the index label of the last email sent
    filt = df.loc[:, 'Referring page URL'] == records.get(title).get("Last")
    last = df.loc[filt].index[0]

    # batch = 30 after last
    batch = df.loc[(last + 1): (last + 31)]

batch
# Out:
#                                     Referring page URL Referring Topic  \
# 93   https://digitalresilience.northeastern.edu/wfa...
# 94   https://ombuds.uconn.edu/resources-for-working...
# 95   https://www.thebulwark.com/how-to-work-from-ho...
# 96          https://georgetownchamber.org/coronavirus/
# 97   https://www.mediaupdate.co.za/media/148202/sev...
# 98   https://www.danby.com/en-uk/blog/working-from-...
# 99   https://sarahscoop.com/how-to-run-your-busines...
# 100  https://www.lux-review.com/what-to-consider-wh...
# 101  https://www.rfchamber.com/coronavirus-business...
# 102  https://www.menstylefashion.com/tips-for-creat...
# 103  https://www.impactplus.com/blog/lessons-learne...
# 104  https://enlabsoftware.com/offshore-software-de...
# 105  https://www.waltonchamber.org/working-from-hom...
# 106  https://blend.ph/4-tips-to-work-from-home-with...
# 107  https://octa.net/getting-around/rideshare/oc-r...
# 108  https://ukmbahasa.poliupg.ac.id/zsygdf/funny-t...
# 109      https://it.ucmerced.edu/CuratedResourcesStaff
# 110  https://cominguprosestheblog.com/august-links-...
# 111  https://www.aussiefirebug.com/may-2020-net-worth/
# 112  https://www.bbntimes.com/technology/productivi...
# 113  https://www.njstatelib.org/author/adauphinee/p...
# 114  https://www.accountingtechniciansireland.ie/ne...
# 115  https://www.peachymama.com.au/blogs/motherhood...
# 116  https://smartway2.com/blog/when-agile-doesnt-w...
# 117  https://nightingalemedical.ca/productivity-wit...
# 118  https://www.replicon.com/blog/eight-tried-and-...
# 119  https://archive.bethebusiness.com/rebuild-your...
# 120  https://www.sherweb.com/blog/partner/7-remote-...
# 121  https://www.yourmove.org.au/resources/working-...
# 122              https://linclearning.com/blog/page/5/
# 123       https://www.ipma.world/how-to-work-remotely/
#
#                                             Target URL  \
# 93   https://blog.hubspot.com/marketing/productivit...
# 94   https://blog.hubspot.com/marketing/productivit...
# 95   https://blog.hubspot.com/marketing/productivit...
# 96   https://blog.hubspot.com/marketing/productivit...
# 97   https://blog.hubspot.com/marketing/productivit...
# 98   https://blog.hubspot.com/marketing/productivit...
# 99   https://blog.hubspot.com/marketing/productivit...
# 100  https://blog.hubspot.com/marketing/productivit...
# 101  https://blog.hubspot.com/marketing/productivit...
# 102  https://blog.hubspot.com/marketing/productivit...
# 103  https://blog.hubspot.com/marketing/productivit...
# 104  https://blog.hubspot.com/marketing/productivit...
# 105  https://blog.hubspot.com/marketing/productivit...
# 106  https://blog.hubspot.com/marketing/productivit...
# 107  https://blog.hubspot.com/marketing/productivit...
# 108  https://blog.hubspot.com/marketing/productivit...
# 109  https://blog.hubspot.com/marketing/productivit...
# 110  https://blog.hubspot.com/marketing/productivit...
# 111  https://blog.hubspot.com/marketing/productivit...
# 112  https://blog.hubspot.com/marketing/productivit...
# 113  https://blog.hubspot.com/marketing/productivit...
# 114  https://blog.hubspot.com/marketing/productivit...
# 115  https://blog.hubspot.com/marketing/productivit...
# 116  https://blog.hubspot.com/marketing/productivit...
# 117  https://blog.hubspot.com/marketing/productivit...
# 118  https://blog.hubspot.com/marketing/productivit...
# 119  https://blog.hubspot.com/marketing/productivit...
# 120  https://blog.hubspot.com/marketing/productivit...
# 121  https://blog.hubspot.com/marketing/productivit...
# 122  https://blog.hubspot.com/marketing/productivit...
# 123  https://blog.hubspot.com/marketing/productivit...
#
#                                     Root URL First Name   Last Name  \
# 93                  https://northeastern.edu       Koen     Pauwels
# 94                         https://uconn.edu     Morgan    Peniston
# 95                    https://thebulwark.com        Tim      Miller
# 96             https://georgetownchamber.org     Cheryl  Brinkmeyer
# 97                 https://mediaupdate.co.za  Sir/Madam
# 98                         https://danby.com   Victoria     Freeman
# 99                    https://sarahscoop.com      Sarah     Ruhlman
# 100                   https://lux-review.com     Edward    Faulkner
# 101                    https://rfchamber.com    Meghann    Witthoft
# 102              https://menstylefashion.com  Sir/Madam
# 103                   https://impactplus.com    Kristen      Harold
# 104                https://enlabsoftware.com  Sir/Madam
# 105                https://waltonchamber.org       Teri      Smiley
# 106                         https://blend.ph     Eloisa    Bautista
# 107                         https://octa.net      Efren   Magdaleno
# 108                    https://poliupg.ac.id      Yusuf       Yunus
# 109                     https://ucmerced.edu     Debbie   Henderson
# 110         https://cominguprosestheblog.com      Erica     Ligenza
# 111                https://aussiefirebug.com  Sir/Madam
# 112                     https://bbntimes.com  Sir/Madam
# 113                   https://njstatelib.org     Sharon     Rawlins
# 114  https://accountingtechniciansireland.ie      Karen   Mcquillan
# 115                https://peachymama.com.au  Sir/Madam
# 116                    https://smartway2.com       John    Anderson
# 117            https://nightingalemedical.ca  Sir/Madam
# 118                     https://replicon.com      Jason   Archibald
# 119                https://bethebusiness.com      James     Gribben
# 120                      https://sherweb.com       Kate      Oneill
# 121                  https://yourmove.org.au      James       Julie
# 122                 https://linclearning.com   Meredith       Lewis
# 123                       https://ipma.world   Reinhard      Wagner
#
#                                       Recipient Email Sent Status Replied  \
# 93                    kpauwels@northeastern.edu
# 94                    morgan.peniston@uconn.edu
# 95                           tim@thebulwark.com
# 96                 cheryl@georgetownchamber.org
# 97                  editorial@mediaupdate.co.za
# 98                           vfreeman@danby.com
# 99                         sarah@sarahscoop.com
# 100                    efaulkner@lux-review.com
# 101                       meghann@rfchamber.com
# 102         gracie.opulanza@menstylefashion.com
# 103                      kharold@impactplus.com
# 104                      info@enlabsoftware.com
# 105                      teri@waltonchamber.org
# 106                    eloisa.bautista@blend.ph
# 107                         emagdaleno@octa.net
# 108                   yusuf_yunus@poliupg.ac.id
# 109                    dhenderson8@ucmerced.edu
# 110              erica@cominguprosestheblog.com
# 111                     hello@aussiefirebug.com
# 112                          hello@bbntimes.com
# 113                     srawlins@njstatelib.org
# 114  kmcquillan@accountingtechniciansireland.ie
# 115                     hello@peachymama.com.au
# 116                     janderson@smartway2.com
# 117                 nswoc@nightingalemedical.ca
# 118                          jason@replicon.com
# 119             james.gribben@bethebusiness.com
# 120                         koneill@sherweb.com
# 121                       james@yourmove.org.au
# 122              meredithlewis@linclearning.com
# 123                  reinhard.wagner@ipma.world
#
#     Converted
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123

# %%
### Safe to Rerun ###
# Fill Target Topic & Target Hyperlink

# Create the "Target Topic" column
batch.loc[:, ['Target Topic', 'Target Hyperlink']] = ''


# Get the list of target URLs
print(batch.loc[:, 'Target URL'].value_counts())


# Create filters for each URL
url_1 = "https://blog.hubspot.com/marketing/productivity-tips-working-from-home"
filt_1 = (batch.loc[:, 'Target URL'] == url_1)

url_2 = "https://blog.hubspot.com/marketing/productivity-tips-working-from-home?__hstc=219294534.b2b47713ef61d04c6d6fede4eb0fd448.1582064984829.1583868321116.1583937752741.59&__hssc=219294534.8.1583937752741&__hsfp=1704468437"
filt_2 = (batch.loc[:, 'Target URL'] == url_2)

# Fill out Target Hyperlink
batch.loc[filt_1, 'Target Hyperlink'] = f"""<a href="{url_1}">the working from home guide by Hubspot</a>"""

if filt_2.any():
    batch.loc[filt_2, 'Target Hyperlink'] = f"""<a href="{url_2}">the working from home guide by Hubspot</a>"""

# Fill out Target Topic: prereferences; e.g. the guide by nerdwallet
batch.loc[filt_1, 'Target Topic'] = "the guide by Hubspot"

if filt_2.any():
    batch.loc[filt_2, 'Target Topic'] = "the guide by Hubspot"
# Out:
# https://blog.hubspot.com/marketing/productivity-tips-working-from-home                                                                                                                                                      30
# https://blog.hubspot.com/marketing/productivity-tips-working-from-home?__hstc=219294534.b2b47713ef61d04c6d6fede4eb0fd448.1582064984829.1583868321116.1583937752741.59&__hssc=219294534.8.1583937752741&__hsfp=1704468437     1
# Name: Target URL, dtype: int64
# C:\Users\Hooman Deghani\AppData\Local\Temp\ipykernel_10516\1485668661.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch.loc[:, ['Target Topic', 'Target Hyperlink']] = ''

# %%
### Safe to rerun ###
# Playground

batch.head()
# Out:
#                                    Referring page URL Referring Topic  \
# 93  https://digitalresilience.northeastern.edu/wfa...
# 94  https://ombuds.uconn.edu/resources-for-working...
# 95  https://www.thebulwark.com/how-to-work-from-ho...
# 96         https://georgetownchamber.org/coronavirus/
# 97  https://www.mediaupdate.co.za/media/148202/sev...
#
#                                            Target URL  \
# 93  https://blog.hubspot.com/marketing/productivit...
# 94  https://blog.hubspot.com/marketing/productivit...
# 95  https://blog.hubspot.com/marketing/productivit...
# 96  https://blog.hubspot.com/marketing/productivit...
# 97  https://blog.hubspot.com/marketing/productivit...
#
#                          Root URL First Name   Last Name  \
# 93       https://northeastern.edu       Koen     Pauwels
# 94              https://uconn.edu     Morgan    Peniston
# 95         https://thebulwark.com        Tim      Miller
# 96  https://georgetownchamber.org     Cheryl  Brinkmeyer
# 97      https://mediaupdate.co.za  Sir/Madam
#
#                        Recipient Email Sent Status Replied Converted  \
# 93     kpauwels@northeastern.edu
# 94     morgan.peniston@uconn.edu
# 95            tim@thebulwark.com
# 96  cheryl@georgetownchamber.org
# 97   editorial@mediaupdate.co.za
#
#             Target Topic                                   Target Hyperlink
# 93  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 94  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 95  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 96  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 97  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...

# %%
# # Fill referring topic by gpt-3.5
# # Fill referring Hyperlink

#df.loc[:, "Referring hyperlink"] = ''

# %%
# Fill "SQ1 URL column"
## first possible url: https://www.squareone.ca/resource-centres/home-buying-selling-moving/buying-a-home-for-the-first-time
## second possible url: https://www.squareone.ca/resource-centres/home-personal-safety/work-from-home-guide
batch.loc[:, 'SQ1 URL'] = 'https://www.squareone.ca/resource-centres/home-personal-safety/work-from-home-guide'
# Out:
# C:\Users\Hooman Deghani\AppData\Local\Temp\ipykernel_10516\1540710788.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch.loc[:, 'SQ1 URL'] = 'https://www.squareone.ca/resource-centres/home-personal-safety/work-from-home-guide'

# %%
# # Push to Gspreadsheet
# spreadsheet_title = "Outreach"
# worksheet_title = f"Last:{batch.loc[batch.tail(1).index[0], 'First Name']}{batch.loc[batch.tail(1).index[0], 'Last Name']}"

# spreadsheet = gc.open(spreadsheet_title)
# worksheet = spreadsheet.add_worksheet(title=worksheet_title, rows=batch.shape[0], cols=batch.shape[1])
# worksheet.update([batch.columns.tolist()] + batch.values.tolist())

# %%
# Save output to input
file_name = f"{batch.loc[batch.tail(1).index[0], 'Recipient']}.csv"
path = r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Input\Current\F"

batch.to_csv(path+file_name)

# %%
# Update records.json #

# Update records with the new variables
records[title]["New"] = "False"
records[title]["Last"] = batch.loc[batch.tail(1).index[0], 'Referring page URL']

# Push records to records.json
with open(r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Records.json", "w") as records_json:
    json.dump(records, records_json)
