# %%
### Safe to rerun ###

import config
import gspread
import json
import openai
import os

import numpy as np
import pandas as pd

# Authorize gspread
gc, authorized_user = gspread.oauth_from_dict(config.gspread_secret_key_personal, config.gspread_auth_key_personal)

# Read Input from directory

directory = r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Output\Current"

## List all CSV files in the directory

urls = [os.path.join(directory, filename) for filename in os.listdir(directory) if filename.endswith('.xlsx')]

if len(urls) > 1:
    df = pd.concat([pd.read_excel(url) for url in urls], ignore_index=True)

else: 
    df = pd.read_excel(urls[0])

# Create a variable for the title of the project
for filename in os.listdir(directory):
    if filename.endswith('.xlsx'):
        # Capture the cryptic name
        artifact_name = filename
        
        # Extract the essence
        title = artifact_name.split('.')[0]

# Load records.json into a python dictionary titled records
with open(r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Records.json", "r") as records_json:
    records = json.load(records_json)

# Check if an entry in records exists with title
if title not in records:
    records[title] = {
        'New': 'True',
        'Last': ''
    }

records
# Out:
# {'fthb': {'New': 'False',
#   'Last': 'https://morganton.com/lifestyles/home-and-garden/real-estate/co-buying-a-house-how-platonic-partners-make-it-work/article_a4c1234a-6a88-5819-9ee1-bfb26cf02a6d.html'},
#  'wfh': {'New': 'False',
#   'Last': 'https://www.thenexthint.com/simple-steps-to-make-working-from-home-work-for-you/11739/'}}

# %%
### Safe to rerun ###

# Clean up the data #
# Make df json compliant
df = df.applymap(str)
df.replace("nan", "", inplace=True)
df = df.applymap(str.strip)

# Remove rows where email is empty
Recipient_null = df.loc[:, 'Recipient'] == ""
df = df.loc[~Recipient_null]

# Reset index
df = df.reset_index(drop=True)

# %%
### Safe to rerun ###
# Prepare the batch #

# TODO: drop Anchor, DR
df = df.drop(columns=['Anchor', 'Domain rating'])

# Create the dic variable
dic = records.get(title)

# if dataframe is new, batch = df.loc[0:30,:]
if dic.get("New") == "True":
    batch = df.loc[0:30,:]

# if dataframe is old, batch = the next 30 after "Last"
if dic.get("New") == "False":

    # Get the index label of the last email sent
    filt = df.loc[:, 'Referring page URL'] == records.get(title).get("Last")
    last = df.loc[filt].index[0]

    # batch = 30 after last
    batch = df.loc[(last + 1): (last + 31)]

batch
# Out:
#                                     Referring page URL Referring Topic  \
# 155  http://www.olimp.turystyka.pl/vza/getting-thin...
# 156  https://geekinsider.com/boost-productivity-whe...
# 157  https://upcea.edu/home-sweet-home-is-not-offic...
# 158  https://blog.naturalwellbeing.com/6-tips-for-n...
# 159  https://www.nya.org/about/healthy-mind-motivat...
# 160  https://blog.fracturedatlas.org/best-resources...
# 161  https://vocal.media/lifehack/tips-on-working-r...
# 162  https://www.belvoir.co.uk/articles/creating-a-...
# 163  http://m.prodia.co.id/en/Content/ViewContentsD...
# 164  https://wearethecity.com/working-top-tips-prod...
# 165  https://midtrans.com/id/blog/tips-untuk-tetap-...
# 166  https://dev.wholewhale.com/tips/nonprofit-work...
# 167  https://www.hk01.com/%E8%81%B7%E5%A0%B4/429787...
# 168  https://remoters.net/9-productivity-tips-for-e...
# 169           https://blog.loomly.com/remote-work-faq/
# 170  https://www.bizjournals.com/charlotte/inno/sto...
# 171     https://primeraeng.com/posts/a-home-based-you/
# 172             https://www.podkasty.info/katalog/3793
# 173  https://mentalitch.com/how-to-find-your-work-l...
# 174  https://staging.county.org/News/Healthy-Byte/2...
# 175  https://corp.kaltura.com/blog/a-guide-to-worki...
# 176  https://www.earthnetworks.com/resources/guides...
# 177  https://www.phillymag.com/be-well-philly/2020/...
# 178  https://mightygadget.com/starting-a-business-w...
# 179  https://lawpreview.barbri.com/taking-1l-year-o...
# 180  https://www.bustle.com/articles/149694-7-ways-...
# 181  http://www.uapb.edu/sites/www/Uploads/coronavi...
# 182  https://pierre.org/your-community/covid-19-too...
# 183  https://coopsandcareers.wit.edu/blog/2021/05/1...
# 184  http://courses.ics.hawaii.edu/ics314s21/readings/
# 185  https://articles.entireweb.com/technology/heli...
#
#                                             Target URL  \
# 155  https://blog.hubspot.com/marketing/productivit...
# 156  https://blog.hubspot.com/marketing/productivit...
# 157  https://blog.hubspot.com/marketing/productivit...
# 158  https://blog.hubspot.com/marketing/productivit...
# 159  https://blog.hubspot.com/marketing/productivit...
# 160  https://blog.hubspot.com/marketing/productivit...
# 161  https://blog.hubspot.com/marketing/productivit...
# 162  https://blog.hubspot.com/marketing/productivit...
# 163  https://blog.hubspot.com/marketing/productivit...
# 164  https://blog.hubspot.com/marketing/productivit...
# 165  https://blog.hubspot.com/marketing/productivit...
# 166  https://blog.hubspot.com/marketing/productivit...
# 167  https://blog.hubspot.com/marketing/productivit...
# 168  https://blog.hubspot.com/marketing/productivit...
# 169  https://blog.hubspot.com/marketing/productivit...
# 170  https://blog.hubspot.com/marketing/productivit...
# 171  https://blog.hubspot.com/marketing/productivit...
# 172  https://blog.hubspot.com/marketing/productivit...
# 173  https://blog.hubspot.com/marketing/productivit...
# 174  https://blog.hubspot.com/marketing/productivit...
# 175  https://blog.hubspot.com/marketing/productivit...
# 176  https://blog.hubspot.com/marketing/productivit...
# 177  https://blog.hubspot.com/marketing/productivit...
# 178  https://blog.hubspot.com/marketing/productivit...
# 179  https://blog.hubspot.com/marketing/productivit...
# 180  https://blog.hubspot.com/marketing/productivit...
# 181  https://blog.hubspot.com/marketing/productivit...
# 182  https://blog.hubspot.com/marketing/productivit...
# 183  https://blog.hubspot.com/marketing/productivit...
# 184  https://blog.hubspot.com/marketing/productivit...
# 185  https://blog.hubspot.com/marketing/productivit...
#
#                          Root URL First Name   Last Name  \
# 155    https://olimp.turystyka.pl  Sir/Madam
# 156       https://geekinsider.com    Matthew      Harris
# 157             https://upcea.edu     Jordan    Dimaggio
# 158  https://naturalwellbeing.com  Sir/Madam
# 159               https://nya.org      Kevin         Roy
# 160    https://fracturedatlas.org     Sophia        Park
# 161           https://vocal.media  Sir/Madam
# 162         https://belvoir.co.uk      James       Smale
# 163          https://prodia.co.id  Sir/Madam
# 164      https://wearethecity.com    Vanessa     Vallely
# 165          https://midtrans.com       Iris         Dan
# 166        https://wholewhale.com     George      Weiner
# 167              https://hk01.com  Sir/Madam
# 168          https://remoters.net  Sir/Madam
# 169            https://loomly.com    Clement     Thibaud
# 170       https://bizjournals.com        Ron       Davis
# 171        https://primeraeng.com        Ken     Panucci
# 172         https://podkasty.info      Borys   Kozielski
# 173        https://mentalitch.com  Sir/Madam
# 174            https://county.org        Amy      Lawson
# 175           https://kaltura.com       Lisa     Bennett
# 176     https://earthnetworks.com       Dave  Oberholzer
# 177         https://phillymag.com    Kristen      Schott
# 178      https://mightygadget.com  Sir/Madam
# 179            https://barbri.com      David      Murray
# 180            https://bustle.com   Michelle      Toglia
# 181              https://uapb.edu       Brad     Mayhugh
# 182            https://pierre.org       Dani      Norden
# 183               https://wit.edu       Tara      Demers
# 184            https://hawaii.edu      Karyl     Garland
# 185         https://entireweb.com     Marcus   Andersson
#
#                             Recipient Email Sent Status Replied Converted
# 155          olimp@olimp.turystyka.pl
# 156           matthew@geekinsider.com
# 157               jdimaggio@upcea.edu
# 158         info@naturalwellbeing.com
# 159                      kroy@nya.org
# 160    sophia.park@fracturedatlas.org
# 161         news_politics@vocal.media
# 162         james.smale@belvoir.co.uk
# 163                tegal@prodia.co.id
# 164  vanessa.vallely@wearethecity.com
# 165                 iris@midtrans.com
# 166             george@wholewhale.com
# 167                    event@hk01.com
# 168                hello@remoters.net
# 169                thibaud@loomly.com
# 170            rdavis@bizjournals.com
# 171           kpanucci@primeraeng.com
# 172               borys@podkasty.info
# 173               info@mentalitch.com
# 174                   amyl@county.org
# 175          lisa.bennett@kaltura.com
# 176     doberholzer@earthnetworks.com
# 177             kschott@phillymag.com
# 178             info@mightygadget.com
# 179           david.murray@barbri.com
# 180               michelle@bustle.com
# 181                 mayhughb@uapb.edu
# 182                dnorden@pierre.org
# 183                  demerst1@wit.edu
# 184                 karyl8@hawaii.edu
# 185    marcus.andersson@entireweb.com

# %%
### Safe to Rerun ###
#### Needs manual edit ####

# Fill Target Topic & Target Hyperlink

# Create the "Target Topic" column
batch.loc[:, ['Target Topic', 'Target Hyperlink']] = ''


# Get the list of target URLs
print(batch.loc[:, 'Target URL'].value_counts())


# Create filters for each URL
url_1 = "https://blog.hubspot.com/marketing/productivity-tips-working-from-home"
filt_1 = (batch.loc[:, 'Target URL'] == url_1)

url_2 = "https://blog.hubspot.com/marketing/productivity-tips-working-from-home?fbclid=IwAR3_CGB5laJiHk1TxnMiA03h-hXzDwOQD1tLdQdXBzFmaQOS2TnSNwil318"
filt_2 = (batch.loc[:, 'Target URL'] == url_2)

url_3 = "https://blog.hubspot.com/marketing/productivity-tips-working-from-home?__hstc=219294534.b2b47713ef61d04c6d6fede4eb0fd448.1582064984829.1583868321116.1583937752741.59&__hssc=219294534.8.1583937752741&__hsfp=1704468437"
filt_3 = (batch.loc[:, 'Target URL'] == url_3)

# Fill out Target Hyperlink
batch.loc[filt_1, 'Target Hyperlink'] = f"""<a href="{url_1}">the working-from-home guide by Hubspot</a>"""

if filt_2.any():
    batch.loc[filt_2, 'Target Hyperlink'] = f"""<a href="{url_2}">the first-time homebuyer guide by Nerdwallet</a>"""

if filt_3.any():
    batch.loc[filt_3, 'Target Hyperlink'] = f"""<a href="{url_3}">the first-time homebuyer guide by Nerdwallet</a>"""

# Fill out Target Topic: prereferences; e.g. the guide by nerdwallet
batch.loc[filt_1, 'Target Topic'] = "the guide by Hubspot"

if filt_2.any():
    batch.loc[filt_2, 'Target Topic'] = "the guide by Hubspot"

if filt_3.any():
    batch.loc[filt_3, 'Target Topic'] = "the guide by Hubspot"
# Out:
# https://blog.hubspot.com/marketing/productivity-tips-working-from-home                                                                                                                                                      29
# https://blog.hubspot.com/marketing/productivity-tips-working-from-home?fbclid=IwAR3_CGB5laJiHk1TxnMiA03h-hXzDwOQD1tLdQdXBzFmaQOS2TnSNwil318                                                                                  1
# https://blog.hubspot.com/marketing/productivity-tips-working-from-home?__hstc=219294534.b2b47713ef61d04c6d6fede4eb0fd448.1582064984829.1583868321116.1583937752741.59&__hssc=219294534.8.1583937752741&__hsfp=1704468437     1
# Name: Target URL, dtype: int64
# C:\Users\Hooman Deghani\AppData\Local\Temp\ipykernel_15436\296134331.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch.loc[:, ['Target Topic', 'Target Hyperlink']] = ''

# %%
### Safe to rerun ###
# Playground

batch.head()
# Out:
#                                     Referring page URL Referring Topic  \
# 155  http://www.olimp.turystyka.pl/vza/getting-thin...
# 156  https://geekinsider.com/boost-productivity-whe...
# 157  https://upcea.edu/home-sweet-home-is-not-offic...
# 158  https://blog.naturalwellbeing.com/6-tips-for-n...
# 159  https://www.nya.org/about/healthy-mind-motivat...
#
#                                             Target URL  \
# 155  https://blog.hubspot.com/marketing/productivit...
# 156  https://blog.hubspot.com/marketing/productivit...
# 157  https://blog.hubspot.com/marketing/productivit...
# 158  https://blog.hubspot.com/marketing/productivit...
# 159  https://blog.hubspot.com/marketing/productivit...
#
#                          Root URL First Name Last Name  \
# 155    https://olimp.turystyka.pl  Sir/Madam
# 156       https://geekinsider.com    Matthew    Harris
# 157             https://upcea.edu     Jordan  Dimaggio
# 158  https://naturalwellbeing.com  Sir/Madam
# 159               https://nya.org      Kevin       Roy
#
#                      Recipient Email Sent Status Replied Converted  \
# 155   olimp@olimp.turystyka.pl
# 156    matthew@geekinsider.com
# 157        jdimaggio@upcea.edu
# 158  info@naturalwellbeing.com
# 159               kroy@nya.org
#
#              Target Topic                                   Target Hyperlink
# 155  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 156  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 157  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 158  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...
# 159  the guide by Hubspot  <a href="https://blog.hubspot.com/marketing/pr...

# %%
# # Fill referring Hyperlink

batch.loc[:, 'Referring Hyperlink'] = ""

# Fill referring topic by gpt-3.5
# Out:
# C:\Users\Hooman Deghani\AppData\Local\Temp\ipykernel_15436\577683250.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch.loc[:, 'Referring Hyperlink'] = ""

# %%
## Safe to Rerun ##
## Needs manual edit ##

# Fill "SQ1 URL column"
## first possible url: https://www.squareone.ca/resource-centres/home-buying-selling-moving/buying-a-home-for-the-first-time
## second possible url: https://www.squareone.ca/resource-centres/home-personal-safety/work-from-home-guide
batch.loc[:, 'SQ1 URL'] = 'https://www.squareone.ca/resource-centres/home-personal-safety/work-from-home-guide'
# Out:
# C:\Users\Hooman Deghani\AppData\Local\Temp\ipykernel_15436\1233216974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch.loc[:, 'SQ1 URL'] = 'https://www.squareone.ca/resource-centres/home-personal-safety/work-from-home-guide'

# %%
# # Push to Gspreadsheet
# spreadsheet_title = "Outreach"
# worksheet_title = f"Last:{batch.loc[batch.tail(1).index[0], 'First Name']}{batch.loc[batch.tail(1).index[0], 'Last Name']}"

# spreadsheet = gc.open(spreadsheet_title)
# worksheet = spreadsheet.add_worksheet(title=worksheet_title, rows=batch.shape[0], cols=batch.shape[1])
# worksheet.update([batch.columns.tolist()] + batch.values.tolist())

# %%
# Save output to input
file_name = f"{batch.loc[batch.tail(1).index[0], 'Recipient']}.csv"
path = r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Input\Current\F"

batch.to_csv(path+file_name)

# %%
# Update records.json #

# Update records with the new variables
records[title]["New"] = "False"
records[title]["Last"] = batch.loc[batch.tail(1).index[0], 'Referring page URL']

# Push records to records.json
with open(r"C:\Users\Hooman Deghani\Python\Data Analysis\Outreach - Skyscraper\Records.json", "w") as records_json:
    json.dump(records, records_json)
